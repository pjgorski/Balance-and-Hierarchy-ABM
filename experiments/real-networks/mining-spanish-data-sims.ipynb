# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/pgorski/Desktop/data/spanish-highschools/Spanish_highschools_stats.csv")
df
# Out:
#     school  num_triads  num_agents  num_a_agents  num_edges  \
# 0   t11_10       40842         386           372       6116
# 1    t11_9       20230         318           298       3863
# 2    t11_8        7468         207           191       1831
# 3    t11_7        5704          80            75       1040
# 4    t11_6        9363         106           103       1637
# 5    t11_5       36823         223           222       3767
# 6    t11_4       11558         110           109       1436
# 7    t11_3       31981         156           151       3101
# 8    t11_2       65164         512           488       8909
# 9    t11_1       34136         232           220       4186
# 10      t1       45760         326           290       5894
# 11      t2       24365         202           175       3011
# 12      t6      143112         534           483      12777
#
#     edges_not_in_triads   density      SLCC  num_s_components      WLCC  ...  \
# ...

# %%
df

# %%
Y = [0.02634407194585889,
 0.005659982296761169,
 0.0026781611430511405,
 0.03259330351874442,
 0.0018589339547280866,
 0.005239937625792011,
 0.0039525669844511,
 0.03836352004326358,
 0.005907065932786901,
 0.006324323791659267,
 0.009122550307672823,
 0.01739154,
 0.005813113220895581]

# %%
X2 = sm.add_constant(df.loc[:, df.columns != 'school'])

est = sm.OLS(Y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):                nan
# Time:                        15:52:02   Log-Likelihood:                 297.96
# No. Observations:                  13   AIC:                            -569.9
# Df Residuals:                       0   BIC:                            -562.6
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.0400        inf         -0        nan         nan         nan
# ...

# %%
df.columns
# Out:
# Index(['school', 'num_triads', 'num_agents', 'num_a_agents', 'num_edges',
#        'edges_not_in_triads', 'density', 'SLCC', 'num_s_components', 'WLCC',
#        'num_w_components', 'tg_edges', 'tg_density', 'tg_SLCC', 'tg_WLCC',
#        'tg_num_s_components', 'tg_num_w_components', 'str_neg', 'weak_neg',
#        'weak_pos', 'str_pos', 'rho', 'deltas0', 'deltas1', 'deltas2',
#        'deltas3', 'boys', 'prosocial_std', 'prosocial_mean', 'soc0', 'soc1',
#        'soc2', 'soc3', 'crt_std', 'crt_mean', 'crt0', 'crt1', 'crt2', 'crt3'],
#       dtype='object')

# %%
# df_part = df[["num_triads", "num_agents", "num_a_agents", "num_edges"]]
# df_part = df[["rho", "deltas0", "deltas1", "deltas3"]] 
# deltas1 gives pvalue 0.08
# df_part = df[["boys", "prosocial_mean", "crt_mean", "deltas3"]] 
# almost all above give pvalue <0.05!
df_part = df[["rho", "WLCC", "deltas1", "deltas3"]] 
# I dont understand. Now WLCC gives smallest pvalue. 


X2 = sm.add_constant(np.log(df_part))

est = sm.OLS(Y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     5.690
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):             0.0181
# Time:                        16:18:22   Log-Likelihood:                 48.030
# No. Observations:                  13   AIC:                            -86.06
# Df Residuals:                       8   BIC:                            -83.24
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1312      0.063     -2.098      0.069      -0.275       0.013
# ...

# %%
est2.pvalues
# Out:
# const      0.073185
# rho        0.083185
# WLCC       0.039212
# deltas1    0.059043
# deltas3    0.797159
# dtype: float64

# %%
plt.plot((df.boys), Y, 'o')

# %%
df_part = df["boys"]
df_part.values


X2 = sm.add_constant(df_part.values)

est = sm.OLS(Y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.329
# Model:                            OLS   Adj. R-squared:                  0.268
# Method:                 Least Squares   F-statistic:                     5.393
# Date:                Thu, 19 Oct 2023   Prob (F-statistic):             0.0404
# Time:                        16:22:57   Log-Likelihood:                 41.870
# No. Observations:                  13   AIC:                            -79.74
# Df Residuals:                      11   BIC:                            -78.61
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1096      0.053     -2.083      0.061      -0.225       0.006
# ...
